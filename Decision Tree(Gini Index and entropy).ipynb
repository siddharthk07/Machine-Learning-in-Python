# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import datasets,cross_validation
import graphviz

# %%
iris = datasets.load_iris()

# %%
clf = DecisionTreeClassifier(max_depth=5,criterion="entropy") # construct a decision tree using entropy as the splitting criteria
clf.fit(iris.data,iris.target)
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
dot_file = tree.export_graphviz(clf.tree_, out_file='tree_d1.dot', feature_names=iris.feature_names)

# %%
with open("tree_d1.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
score = cross_validation.cross_val_score(clf, iris.data, iris.target, n_jobs=1)
score
# Out:
# array([ 0.98039216,  0.92156863,  0.97916667])

# %%
clf = DecisionTreeClassifier(max_depth=5,criterion="gini") # construct a decision tree using entropy as the splitting criteria
clf.fit(iris.data,iris.target)
clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
dot_file = tree.export_graphviz(clf.tree_, out_file='tree_d1.dot', feature_names=iris.feature_names)
with open("tree_d1.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
score = cross_validation.cross_val_score(clf, iris.data, iris.target, n_jobs=1)
score
# Out:
# array([ 0.98039216,  0.92156863,  1.        ])
